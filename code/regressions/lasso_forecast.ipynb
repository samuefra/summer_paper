# %% [markdown]
# ## LASSO Forecast
#
# Esse notebook tem como objetivo estimar a variável de previsão a partir do LASSO, $f_{n, t}^{\mathrm{LASSO}}$.
#
# $$
# f_{n, t}^{\mathrm{LASSO}} \stackrel{\text { def }}{=} \tilde{\alpha}_n+\sum_{n^{\prime}=1}^{3 \cdot N} \tilde{\beta}_{n, n^{\prime}} \cdot x_{n^{\prime}, t}
# $$
#
# onde $x_{n^{\prime}, t}$ é o retorno do ativo $n^{\prime}$ padronizado para ter média nula e variância unitária dentro da janela de estimação de 30 minutos.

# %%
# pacotes
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV

# %%
# oculta mensagens de avisos
import warnings
warnings.filterwarnings("ignore")

# %%
x = pd.read_csv('../../output/data/20030102_x.csv', index_col=0)

# %%
x = x[3:-1]

# %%
x
# Out:
#           A(t-1)    A(t-2)    A(t-3)   AA(t-1)   AA(t-2)   AA(t-3)  AAAB(t-1)  \
# Time
# 93400   0.005464  0.001645  0.000000  0.002167 -0.001734  0.002602        0.0
# 93500  -0.001091  0.005464  0.001645  0.000865  0.002167 -0.001734        0.0
# 93600   0.000000 -0.001091  0.005464  0.000000  0.000865  0.002167        0.0
# 93700   0.001635  0.000000 -0.001091 -0.002599  0.000000  0.000865        0.0
# 93800   0.000545  0.001635  0.000000 -0.002171 -0.002599  0.000000        0.0
# ...          ...       ...       ...       ...       ...       ...        ...
# 155500  0.000522  0.000000  0.000000  0.000000  0.000000 -0.000424        0.0
# 155600  0.000000  0.000522  0.000000  0.001696  0.000000  0.000000        0.0
# 155700  0.000000  0.000000  0.000522 -0.000424  0.001696  0.000000        0.0
# 155800 -0.001043  0.000000  0.000000  0.000000 -0.000424  0.001696        0.0
# 155900  0.000000 -0.001043  0.000000 -0.000848  0.000000 -0.000424        0.0
#
#         AAAB(t-2)  AAAB(t-3)  AAC(t-1)  ...  ZOOM(t-3)  ZQK(t-1)  ZQK(t-2)  \
# Time                                    ...
# 93400         0.0        0.0       0.0  ...        0.0  0.000000  0.000000
# 93500         0.0        0.0       0.0  ...        0.0  0.000371  0.000000
# 93600         0.0        0.0       0.0  ...        0.0  0.000370  0.000371
# 93700         0.0        0.0       0.0  ...        0.0  0.003697  0.000370
# 93800         0.0        0.0       0.0  ...        0.0  0.000000  0.003697
# ...           ...        ...       ...  ...        ...       ...       ...
# 155500        0.0        0.0       0.0  ...        0.0  0.000000  0.000000
# 155600        0.0        0.0       0.0  ...        0.0  0.000000  0.000000
# 155700        0.0        0.0       0.0  ...        0.0  0.001096  0.000000
# 155800        0.0        0.0       0.0  ...        0.0  0.000730  0.001096
# 155900        0.0        0.0       0.0  ...        0.0  0.000365  0.000730
#
#         ZQK(t-3)  ZRAN(t-1)  ZRAN(t-2)  ZRAN(t-3)  ZTEL(t-1)  ZTEL(t-2)  \
# Time
# 93400   0.000000  -0.002073  -0.002068   0.016667        0.0        0.0
# 93500   0.000000   0.005724  -0.002073  -0.002068        0.0        0.0
# 93600   0.000000  -0.007800   0.005724  -0.002073        0.0        0.0
# 93700   0.000371  -0.004863  -0.007800   0.005724        0.0        0.0
# 93800   0.000370  -0.000871  -0.004863  -0.007800        0.0        0.0
# ...          ...        ...        ...        ...        ...        ...
# 155500  0.000000   0.001923   0.000000  -0.000995        0.0        0.0
# 155600  0.000000  -0.000596   0.001923   0.000000        0.0        0.0
# 155700  0.000000   0.001655  -0.000596   0.001923        0.0        0.0
# 155800  0.000000  -0.001655   0.001655  -0.000596        0.0        0.0
# 155900  0.001096   0.006605  -0.001655   0.001655        0.0        0.0
#
#         ZTEL(t-3)
# Time
# 93400   -0.140357
# 93500    0.000000
# 93600    0.000000
# 93700    0.000000
# 93800    0.000000
# ...           ...
# 155500   0.000000
# 155600   0.000000
# 155700   0.000000
# 155800   0.000000
# 155900   0.000000
#
# [386 rows x 14133 columns]

# %%
y = pd.read_csv('../../output/data/20030102_y.csv', index_col=0)

# %%
y = y[3:-1]

# %%
y
# Out:
#         IFUL(t)    RMD(t)     NI(t)   HYSQ(t)    HSC(t)   ACDO(t)   GNLB(t)  \
# Time
# 93400       0.0  0.000000  0.000499  0.000000  0.000313 -0.000568  0.005731
# 93500       0.0  0.000000  0.000000  0.000000  0.000000 -0.001421 -0.028988
# 93600       0.0  0.000000  0.000998  0.000000  0.000000 -0.001708  0.000000
# 93700       0.0  0.000000 -0.002497  0.000000  0.000313 -0.003426  0.000000
# 93800       0.0  0.000000  0.002497  0.000000  0.000000 -0.003437  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 155500      0.0  0.000000 -0.002440  0.000000  0.000000  0.000827  0.000000
# 155600      0.0  0.000000 -0.001956 -0.000602  0.000000 -0.001103  0.000000
# 155700      0.0  0.000322  0.000489  0.000000  0.001547  0.000000  0.000000
# 155800      0.0  0.000000 -0.000979  0.000000  0.000927  0.000000  0.000000
# 155900      0.0  0.000645  0.002934  0.000000 -0.000618 -0.001656  0.000000
#
#         DRVR(t)  BJCT(t)     SP(t)  ...   BPRX(t)    DLX(t)   RRGB(t)  \
# Time                                ...
# 93400       0.0      0.0  0.003069  ...  0.000000  0.000000  0.000000
# 93500       0.0      0.0  0.000000  ...  0.000000 -0.000953  0.000000
# 93600       0.0      0.0 -0.001022  ...  0.000000  0.000477  0.000000
# 93700       0.0      0.0  0.004082  ...  0.000000  0.000238  0.000000
# 93800       0.0      0.0  0.000000  ...  0.000000  0.000000  0.000000
# ...         ...      ...       ...  ...       ...       ...       ...
# 155500      0.0      0.0  0.000000  ...  0.000000  0.000000  0.003920
# 155600      0.0      0.0 -0.001043  ...  0.000000  0.000238 -0.000039
# 155700      0.0      0.0 -0.001044  ...  0.003656  0.000000  0.000039
# 155800      0.0      0.0  0.000000  ... -0.001461 -0.000238  0.004294
# 155900      0.0      0.0  0.000000  ...  0.000000  0.000238 -0.016893
#
#          PLUM(t)  CALA(t)    DHB(t)    RRA(t)   RMHT(t)  FDTR(t)   DRRX(t)
# Time
# 93400   0.000000      0.0  0.000000  0.000000  0.000000      0.0 -0.004728
# 93500   0.000000      0.0  0.000000  0.000000  0.000000      0.0  0.000000
# 93600   0.000000      0.0  0.000000  0.000000  0.000000      0.0  0.000000
# 93700   0.000000      0.0  0.000000  0.000000  0.000000      0.0  0.000000
# 93800   0.000000      0.0  0.000000  0.000000  0.000000      0.0  0.004728
# ...          ...      ...       ...       ...       ...      ...       ...
# 155500 -0.003824      0.0  0.000000  0.000000  0.000000      0.0  0.000000
# 155600  0.000000      0.0  0.000000  0.002732  0.000000      0.0  0.000000
# 155700  0.000000      0.0  0.000000  0.004084  0.007737      0.0  0.000000
# 155800  0.003824      0.0  0.000000  0.000000 -0.007737      0.0  0.000000
# 155900  0.011197      0.0  0.006192  0.000000  0.000000      0.0  0.000000
#
# [386 rows x 250 columns]

# %%
x_temp = x[0:30]

# %%
x_temp = ( x_temp - x_temp.mean() ) / x_temp.std()

# %%
x_temp = x_temp.dropna(axis=1)

# %%
y_temp = y[0:30]

# %%
model = LassoCV(cv=10, random_state=0, max_iter=10000)

# %%
model.fit(x_temp, y_temp.iloc[:,2])
# Out:
# LassoCV(cv=10, max_iter=10000, random_state=0)

# %%
model.alpha_
# Out:
# 0.0006724548048336852

# %%
reg = Lasso(alpha=model.alpha_)

# %%
reg.fit(x_temp, y_temp.iloc[:,2])
# Out:
# Lasso(alpha=0.0006724548048336852)

# %%
# coeficientes
list(zip(reg.coef_, x_temp))
# Out:
# [(0.0, 'A(t-1)'),
#  (0.0, 'A(t-2)'),
#  (0.0, 'A(t-3)'),
#  (0.0, 'AA(t-1)'),
#  (-0.0, 'AA(t-2)'),
#  (-0.0, 'AA(t-3)'),
#  (-0.0, 'AAI(t-1)'),
#  (0.0, 'AAI(t-2)'),
#  (0.0, 'AAI(t-3)'),
#  (0.0, 'AAII(t-1)'),
#  (-0.0, 'AAII(t-2)'),
#  (-0.0, 'AAII(t-3)'),
#  (0.0, 'AANB(t-1)'),
#  (0.0, 'AANB(t-2)'),
#  (0.0, 'AANB(t-3)'),
#  (-0.0, 'AAP(t-1)'),
#  (-0.0, 'AAP(t-2)'),
#  (0.0, 'AAP(t-3)'),
#  (0.0, 'AAPL(t-1)'),
#  (-0.0, 'AAPL(t-2)'),
#  (0.0, 'AAPL(t-3)'),
#  (0.0, 'ABAX(t-3)'),
#  (0.0, 'ABBK(t-1)'),
#  (-0.0, 'ABBK(t-2)'),
#  (0.0, 'ABBK(t-3)'),
#  (0.0, 'ABC(t-1)'),
#  (-0.0, 'ABC(t-2)'),
#  (-0.0, 'ABC(t-3)'),
#  (-0.0, 'ABCB(t-1)'),
#  (-0.0, 'ABCB(t-2)'),
#  (0.0, 'ABCB(t-3)'),
#  (-0.0, 'ABCO(t-1)'),
#  (-0.0, 'ABCO(t-2)'),
#  (0.0, 'ABCO(t-3)'),
#  (0.0, 'ABCW(t-3)'),
#  (0.0, 'ABCX(t-1)'),
#  (-0.0, 'ABCX(t-2)'),
#  (-0.0, 'ABCX(t-3)'),
#  (0.0, 'ABF(t-1)'),
#  (-0.0, 'ABF(t-2)'),
#  (-0.0, 'ABF(t-3)'),
#  (0.0, 'ABFS(t-1)'),
#  (-0.0, 'ABFS(t-2)'),
#  (0.0, 'ABFS(t-3)'),
#  (0.0, 'ABG(t-1)'),
#  (-0.0, 'ABG(t-2)'),
#  (0.0, 'ABG(t-3)'),
#  (-0.0, 'ABGX(t-1)'),
#  (-0.0, 'ABGX(t-2)'),
#  (-0.0, 'ABGX(t-3)'),
#  (0.0, 'ABI(t-1)'),
#  (-0.0, 'ABI(t-2)'),
#  (-0.0, 'ABI(t-3)'),
#  (0.0, 'ABK(t-1)'),
#  (-0.0, 'ABK(t-2)'),
#  (-0.0, 'ABK(t-3)'),
#  (0.0, 'ABM(t-1)'),
#  (-0.0, 'ABM(t-2)'),
#  (0.0, 'ABM(t-3)'),
#  (-0.0, 'ABMD(t-1)'),
#  (0.0, 'ABMD(t-2)'),
#  (-0.0, 'ABMD(t-3)'),
#  (-0.0, 'ABP(t-1)'),
#  (0.0, 'ABP(t-2)'),
#  (-0.0, 'ABP(t-3)'),
#  (-0.0, 'ABRX(t-1)'),
#  (-0.0, 'ABRX(t-2)'),
#  (-0.0, 'ABRX(t-3)'),
#  (-0.0, 'ABS(t-1)'),
#  (-0.0, 'ABS(t-2)'),
#  (-0.0, 'ABS(t-3)'),
#  (-0.0, 'ABT(t-1)'),
#  (0.0, 'ABT(t-2)'),
#  (-0.0, 'ABT(t-3)'),
#  (0.0, 'ABTL(t-2)'),
#  (0.0, 'ABTL(t-3)'),
#  (-0.0, 'ACAI(t-1)'),
#  (0.0, 'ACAI(t-2)'),
#  (-0.0, 'ACAI(t-3)'),
#  (0.0, 'ACAP(t-1)'),
#  (-0.0, 'ACAP(t-2)'),
#  (0.0, 'ACAP(t-3)'),
#  (-0.0, 'ACAS(t-1)'),
#  (-0.0, 'ACAS(t-2)'),
#  (0.0, 'ACAS(t-3)'),
#  (-0.0, 'ACAT(t-1)'),
#  (-0.0, 'ACAT(t-2)'),
#  (0.0, 'ACAT(t-3)'),
#  (-0.0, 'ACDO(t-1)'),
#  (0.0, 'ACDO(t-2)'),
#  (0.0, 'ACDO(t-3)'),
#  (-0.0, 'ACET(t-1)'),
#  (0.0, 'ACET(t-2)'),
#  (-0.0, 'ACET(t-3)'),
#  (-0.0, 'ACF(t-1)'),
#  (0.0, 'ACF(t-2)'),
#  (-0.0, 'ACF(t-3)'),
#  (-0.0, 'ACI(t-1)'),
#  (0.0, 'ACI(t-2)'),
#  (0.0, 'ACI(t-3)'),
#  (-0.0, 'ACLA(t-1)'),
#  (-0.0, 'ACLA(t-2)'),
#  (0.0, 'ACLA(t-3)'),
#  (0.0, 'ACLS(t-1)'),
#  (-0.0, 'ACLS(t-2)'),
#  (-0.0, 'ACLS(t-3)'),
#  (-0.0, 'ACME(t-3)'),
#  (0.0, 'ACMR(t-1)'),
#  (-0.0, 'ACMR(t-2)'),
#  (0.0, 'ACMR(t-3)'),
#  (-0.0, 'ACO(t-1)'),
#  (-0.0, 'ACO(t-2)'),
#  (0.0, 'ACO(t-3)'),
#  (0.0, 'ACPW(t-1)'),
#  (0.0, 'ACPW(t-2)'),
#  (-0.0, 'ACPW(t-3)'),
#  (0.0, 'ACS(t-1)'),
#  (0.0, 'ACS(t-2)'),
#  (-0.0, 'ACS(t-3)'),
#  (-0.0, 'ACTG(t-1)'),
#  (0.0, 'ACTG(t-2)'),
#  (-0.0, 'ACTG(t-3)'),
#  (0.0, 'ACTL(t-1)'),
#  (-0.0, 'ACTL(t-2)'),
#  (0.0, 'ACTL(t-3)'),
#  (-0.0, 'ACTR(t-1)'),
#  (-0.0, 'ACTR(t-2)'),
#  (-0.0, 'ACTR(t-3)'),
#  (-0.0, 'ACTT(t-1)'),
#  (0.0, 'ACTT(t-2)'),
#  (-0.0, 'ACTT(t-3)'),
#  (-0.0, 'ACTU(t-1)'),
#  (0.0, 'ACTU(t-2)'),
#  (0.0, 'ACTU(t-3)'),
#  (0.0, 'ACV(t-1)'),
#  (0.0, 'ACV(t-2)'),
#  (0.0, 'ACV(t-3)'),
#  (0.0, 'ACVA(t-1)'),
#  (0.0, 'ACVA(t-2)'),
#  (-0.0, 'ACVA(t-3)'),
#  (-0.0, 'ACXM(t-1)'),
#  (0.0, 'ACXM(t-2)'),
#  (0.0, 'ACXM(t-3)'),
#  (-0.0, 'AD(t-1)'),
#  (-0.0, 'AD(t-2)'),
#  (0.0, 'AD(t-3)'),
#  (0.0, 'ADAM(t-1)'),
#  (-0.0, 'ADAM(t-2)'),
#  (0.0, 'ADAM(t-3)'),
#  (0.0, 'ADAT(t-1)'),
#  (-0.0, 'ADAT(t-2)'),
#  (0.0, 'ADAT(t-3)'),
#  (-0.0, 'ADBE(t-1)'),
#  (-0.0, 'ADBE(t-2)'),
#  (-0.0, 'ADBE(t-3)'),
#  (0.0, 'ADBL(t-1)'),
#  (0.0, 'ADBL(t-2)'),
#  (0.0, 'ADCT(t-1)'),
#  (-0.0, 'ADCT(t-2)'),
#  (0.0, 'ADCT(t-3)'),
#  (-0.0, 'ADEX(t-1)'),
#  (-0.0, 'ADG(t-1)'),
#  (0.0, 'ADG(t-2)'),
#  (0.0, 'ADG(t-3)'),
#  (0.0, 'ADI(t-1)'),
#  (0.0, 'ADI(t-2)'),
#  (-0.0, 'ADI(t-3)'),
#  (0.0, 'ADIC(t-1)'),
#  (0.0, 'ADIC(t-2)'),
#  (0.0, 'ADIC(t-3)'),
#  (0.0, 'ADLI(t-3)'),
#  (0.0, 'ADLR(t-1)'),
#  (0.0, 'ADLR(t-2)'),
#  (0.0, 'ADLR(t-3)'),
#  (0.0, 'ADLT(t-1)'),
#  (-0.0, 'ADLT(t-2)'),
#  (-0.0, 'ADLT(t-3)'),
#  (0.0, 'ADM(t-1)'),
#  (0.0, 'ADM(t-2)'),
#  (-0.0, 'ADM(t-3)'),
#  (0.0, 'ADP(t-1)'),
#  (-0.0, 'ADP(t-2)'),
#  (-0.0, 'ADP(t-3)'),
#  (-0.0, 'ADPT(t-1)'),
#  (-0.0, 'ADPT(t-2)'),
#  (-0.0, 'ADPT(t-3)'),
#  (-0.0, 'ADRX(t-1)'),
#  (-0.0, 'ADRX(t-2)'),
#  (0.0, 'ADRX(t-3)'),
#  (0.0, 'ADS(t-1)'),
#  (0.0, 'ADS(t-2)'),
#  (0.0, 'ADS(t-3)'),
#  (0.0, 'ADSK(t-1)'),
#  (-0.0, 'ADSK(t-2)'),
#  (-0.0, 'ADSK(t-3)'),
#  (0.0, 'ADSX(t-1)'),
#  (-0.0, 'ADSX(t-2)'),
#  (-0.0, 'ADSX(t-3)'),
#  (0.0, 'ADTK(t-1)'),
#  (0.0, 'ADTK(t-2)'),
#  (0.0, 'ADTK(t-3)'),
#  (-0.0, 'ADTN(t-1)'),
#  (0.0, 'ADTN(t-2)'),
#  (0.0, 'ADTN(t-3)'),
#  (0.0, 'ADVNA(t-1)'),
#  (-0.0, 'ADVNA(t-2)'),
#  (0.0, 'ADVNA(t-3)'),
#  (0.0, 'ADVNB(t-1)'),
#  (0.0, 'ADVNB(t-2)'),
#  (0.0, 'ADVNB(t-3)'),
#  (0.0, 'ADVP(t-1)'),
#  (0.0, 'ADVP(t-2)'),
#  (-0.0, 'ADVP(t-3)'),
#  (-0.0, 'ADVS(t-1)'),
#  (-0.0, 'ADVS(t-2)'),
#  (-0.0, 'ADVS(t-3)'),
#  (-0.0, 'AEE(t-1)'),
#  (0.0, 'AEE(t-2)'),
#  (-0.0, 'AEE(t-3)'),
#  (-0.0, 'AEIS(t-1)'),
#  (-0.0, 'AEIS(t-2)'),
#  (0.0, 'AEIS(t-3)'),
#  (-0.0, 'AEN(t-1)'),
#  (0.0, 'AEN(t-2)'),
#  (0.0, 'AEN(t-3)'),
#  (0.0, 'AEOS(t-1)'),
#  (0.0, 'AEOS(t-2)'),
#  (-0.0, 'AEOS(t-3)'),
#  (0.0, 'AEP(t-1)'),
#  (0.0, 'AEP(t-2)'),
#  (-0.0, 'AEP(t-3)'),
#  (0.0, 'AEPI(t-1)'),
#  (0.0, 'AEPI(t-2)'),
#  (0.0, 'AEPI(t-3)'),
#  (0.0, 'AES(t-1)'),
#  (-0.0, 'AES(t-2)'),
#  (0.0, 'AES(t-3)'),
#  (0.0, 'AET(t-1)'),
#  (-0.0, 'AET(t-2)'),
#  (-0.0, 'AET(t-3)'),
#  (-0.0, 'AETC(t-1)'),
#  (0.0, 'AETC(t-2)'),
#  (0.0, 'AETC(t-3)'),
#  (0.0, 'AETH(t-1)'),
#  (0.0, 'AETH(t-2)'),
#  (0.0, 'AETH(t-3)'),
#  (0.0, 'AF(t-1)'),
#  (0.0, 'AF(t-2)'),
#  (0.0, 'AF(t-3)'),
#  (0.0, 'AFC(t-1)'),
#  (0.0, 'AFC(t-2)'),
#  (0.0, 'AFC(t-3)'),
#  (-0.0, 'AFCE(t-1)'),
#  (0.0, 'AFCE(t-2)'),
#  (0.0, 'AFCE(t-3)'),
#  (0.0, 'AFCI(t-1)'),
#  (-0.0, 'AFCI(t-2)'),
#  (-0.0, 'AFCI(t-3)'),
#  (-0.0, 'AFCO(t-1)'),
#  (0.0, 'AFCO(t-2)'),
#  (0.0, 'AFCO(t-3)'),
#  (0.0, 'AFFX(t-1)'),
#  (-0.0, 'AFFX(t-2)'),
#  (-0.0, 'AFFX(t-3)'),
#  (0.0, 'AFG(t-1)'),
#  (0.0, 'AFG(t-2)'),
#  (0.0, 'AFG(t-3)'),
#  (0.0, 'AFL(t-1)'),
#  (0.0, 'AFL(t-2)'),
#  (-0.0, 'AFL(t-3)'),
#  (0.0, 'AG(t-1)'),
#  (-0.0, 'AG(t-2)'),
#  (-0.0, 'AG(t-3)'),
#  (0.0, 'AGAM(t-1)'),
#  (-0.0, 'AGAM(t-2)'),
#  (-0.0, 'AGAM(t-3)'),
#  (-0.0, 'AGE(t-1)'),
#  (-0.0, 'AGE(t-2)'),
#  (0.0, 'AGE(t-3)'),
#  (-0.0, 'AGEN(t-1)'),
#  (0.0, 'AGEN(t-2)'),
#  (0.0, 'AGEN(t-3)'),
#  (0.0, 'AGI(t-1)'),
#  (-0.0, 'AGI(t-2)'),
#  (-0.0, 'AGI(t-3)'),
#  (0.0, 'AGII(t-1)'),
#  (0.0, 'AGII(t-2)'),
#  (-0.0, 'AGII(t-3)'),
#  (0.0, 'AGIL(t-1)'),
#  (0.0, 'AGIL(t-2)'),
#  (-0.0, 'AGIL(t-3)'),
#  (0.0, 'AGIX(t-1)'),
#  (-0.0, 'AGIX(t-2)'),
#  (0.0, 'AGIX(t-3)'),
#  (-0.0, 'AGL(t-1)'),
#  (0.0, 'AGL(t-2)'),
#  (0.0, 'AGL(t-3)'),
#  (0.0, 'AGM(t-1)'),
#  (0.0, 'AGM(t-2)'),
#  (-0.0, 'AGM(t-3)'),
#  (0.0, 'AGN(t-1)'),
#  (0.0, 'AGN(t-2)'),
#  (-0.0, 'AGN(t-3)'),
#  (-0.0, 'AGRA(t-1)'),
#  (0.0, 'AGRA(t-2)'),
#  (-0.0, 'AGRA(t-3)'),
#  (-0.0, 'AGRB(t-1)'),
#  (-0.0, 'AGRB(t-2)'),
#  (0.0, 'AGRB(t-3)'),
#  (0.0, 'AGY(t-1)'),
#  (-0.0, 'AGY(t-2)'),
#  (0.0, 'AGY(t-3)'),
#  (-0.0, 'AH(t-1)'),
#  (-0.0, 'AH(t-2)'),
#  (-0.0, 'AH(t-3)'),
#  (-0.0, 'AHC(t-1)'),
#  (-0.0, 'AHC(t-2)'),
#  (-0.0, 'AHC(t-3)'),
#  (0.0, 'AHG(t-1)'),
#  (-0.0, 'AHG(t-2)'),
#  (0.0, 'AHG(t-3)'),
#  (0.0, 'AHLS(t-2)'),
#  (-0.0, 'AHLS(t-3)'),
#  (0.0, 'AHMH(t-1)'),
#  (-0.0, 'AHMH(t-2)'),
#  (-0.0, 'AHMH(t-3)'),
#  (0.0, 'AHS(t-1)'),
#  (0.0, 'AHS(t-2)'),
#  (-0.0, 'AHS(t-3)'),
#  (0.0, 'AICX(t-1)'),
#  (-0.0, 'AICX(t-2)'),
#  (0.0, 'AICX(t-3)'),
#  (0.0, 'AIG(t-1)'),
#  (-0.0, 'AIG(t-2)'),
#  (-0.0, 'AIG(t-3)'),
#  (0.0, 'AIN(t-1)'),
#  (0.0, 'AIN(t-2)'),
#  (0.0, 'AIN(t-3)'),
#  (-0.0, 'AINN(t-3)'),
#  (0.0, 'AIQ(t-1)'),
#  (-0.0, 'AIQ(t-2)'),
#  (0.0, 'AIQ(t-3)'),
#  (-0.0, 'AIR(t-1)'),
#  (0.0, 'AIR(t-2)'),
#  (-0.0, 'AIR(t-3)'),
#  (0.0, 'AIRM(t-1)'),
#  (-0.0, 'AIRM(t-2)'),
#  (0.0, 'AIRM(t-3)'),
#  (0.0, 'AIRN(t-1)'),
#  (-0.0, 'AIRN(t-2)'),
#  (0.0, 'AIRN(t-3)'),
#  (-0.0, 'AIT(t-1)'),
#  (0.0, 'AIT(t-2)'),
#  (-0.0, 'AIT(t-3)'),
#  (-0.0, 'AIZ(t-1)'),
#  (-0.0, 'AIZ(t-2)'),
#  (-0.0, 'AIZ(t-3)'),
#  (-0.0, 'AJG(t-1)'),
#  (0.0, 'AJG(t-2)'),
#  (-0.0, 'AJG(t-3)'),
#  (0.0, 'AKAM(t-1)'),
#  (-0.0, 'AKAM(t-2)'),
#  (0.0, 'AKAM(t-3)'),
#  (0.0, 'AKLM(t-1)'),
#  (-0.0, 'AKLM(t-2)'),
#  (-0.0, 'AKLM(t-3)'),
#  (-0.0, 'AKS(t-1)'),
#  (0.0, 'AKS(t-2)'),
#  (0.0, 'AKS(t-3)'),
#  (0.0, 'AKSY(t-1)'),
#  (0.0, 'AKSY(t-2)'),
#  (0.0, 'AKSY(t-3)'),
#  (0.0, 'ALAB(t-1)'),
#  (0.0, 'ALAB(t-2)'),
#  (0.0, 'ALAB(t-3)'),
#  (-0.0, 'ALB(t-1)'),
#  (0.0, 'ALB(t-2)'),
#  (0.0, 'ALB(t-3)'),
#  (-0.0, 'ALCO(t-1)'),
#  (-0.0, 'ALCO(t-2)'),
#  (0.0, 'ALCO(t-3)'),
#  (0.0, 'ALD(t-1)'),
#  (0.0, 'ALD(t-2)'),
#  (-0.0, 'ALD(t-3)'),
#  (-0.0, 'ALE(t-1)'),
#  (-0.0, 'ALE(t-2)'),
#  (0.0, 'ALE(t-3)'),
#  (0.0, 'ALEX(t-1)'),
#  (0.0, 'ALEX(t-2)'),
#  (-0.0, 'ALEX(t-3)'),
#  (0.0, 'ALFA(t-1)'),
#  (0.0, 'ALFA(t-2)'),
#  (0.0, 'ALFA(t-3)'),
#  (-0.0, 'ALG(t-1)'),
#  (0.0, 'ALGN(t-1)'),
#  (0.0, 'ALGN(t-2)'),
#  (0.0, 'ALGN(t-3)'),
#  (-0.0, 'ALGX(t-1)'),
#  (-0.0, 'ALGX(t-2)'),
#  (-0.0, 'ALGX(t-3)'),
#  (0.0, 'ALI(t-1)'),
#  (0.0, 'ALI(t-2)'),
#  (0.0, 'ALI(t-3)'),
#  (-0.0, 'ALK(t-1)'),
#  (0.0, 'ALK(t-2)'),
#  (0.0, 'ALK(t-3)'),
#  (0.0, 'ALKS(t-1)'),
#  (-0.0, 'ALKS(t-2)'),
#  (-0.0, 'ALKS(t-3)'),
#  (0.0, 'ALL(t-1)'),
#  (0.0, 'ALL(t-2)'),
#  (-0.0, 'ALL(t-3)'),
#  (0.0, 'ALLE(t-1)'),
#  (-0.0, 'ALLE(t-2)'),
#  (-0.0, 'ALLE(t-3)'),
#  (0.0, 'ALN(t-1)'),
#  (0.0, 'ALN(t-2)'),
#  (0.0, 'ALN(t-3)'),
#  (-0.0, 'ALO(t-1)'),
#  (-0.0, 'ALO(t-2)'),
#  (0.0, 'ALO(t-3)'),
#  (0.0, 'ALOG(t-1)'),
#  (-0.0, 'ALOG(t-2)'),
#  (-0.0, 'ALOG(t-3)'),
#  (-0.0, 'ALOY(t-1)'),
#  (-0.0, 'ALOY(t-2)'),
#  (0.0, 'ALOY(t-3)'),
#  (-0.0, 'ALSC(t-1)'),
#  (0.0, 'ALSC(t-2)'),
#  (0.0, 'ALSC(t-3)'),
#  (0.0, 'ALSK(t-1)'),
#  (-0.0, 'ALSK(t-2)'),
#  (-0.0, 'ALSK(t-3)'),
#  (-0.0, 'ALT(t-1)'),
#  (0.0, 'ALT(t-2)'),
#  (-0.0, 'ALT(t-3)'),
#  (-0.0, 'ALTH(t-1)'),
#  (0.0, 'ALTH(t-2)'),
#  (-0.0, 'ALTH(t-3)'),
#  (0.0, 'ALTR(t-1)'),
#  (0.0, 'ALTR(t-2)'),
#  (-0.0, 'ALTR(t-3)'),
#  (0.0, 'ALV(t-1)'),
#  (-0.0, 'ALV(t-2)'),
#  (0.0, 'ALV(t-3)'),
#  (-0.0, 'ALXN(t-1)'),
#  (0.0, 'ALXN(t-2)'),
#  (-0.0, 'ALXN(t-3)'),
#  (-0.0, 'AM(t-1)'),
#  (-0.0, 'AM(t-2)'),
#  (-0.0, 'AM(t-3)'),
#  (-0.0, 'AMAT(t-1)'),
#  (0.0, 'AMAT(t-2)'),
#  (-0.0, 'AMAT(t-3)'),
#  (0.0, 'AMCC(t-1)'),
#  (0.0, 'AMCC(t-2)'),
#  (0.0, 'AMCC(t-3)'),
#  (-0.0, 'AMD(t-1)'),
#  (0.0, 'AMD(t-2)'),
#  (-0.0, 'AMD(t-3)'),
#  (-0.0, 'AME(t-1)'),
#  (0.0, 'AME(t-2)'),
#  (-0.0, 'AME(t-3)'),
#  (-0.0, 'AMED(t-1)'),
#  (-0.0, 'AMED(t-2)'),
#  (-0.0, 'AMED(t-3)'),
#  (0.0, 'AMEV(t-1)'),
#  (-0.0, 'AMEV(t-2)'),
#  (-0.0, 'AMEV(t-3)'),
#  (0.0, 'AMFH(t-1)'),
#  (0.0, 'AMFH(t-2)'),
#  (0.0, 'AMFH(t-3)'),
#  (0.0, 'AMFI(t-1)'),
#  (-0.0, 'AMFI(t-2)'),
#  (-0.0, 'AMFI(t-3)'),
#  (-0.0, 'AMG(t-1)'),
#  (0.0, 'AMG(t-2)'),
#  (0.0, 'AMG(t-3)'),
#  (-0.0, 'AMGIA(t-1)'),
#  (-0.0, 'AMGIA(t-2)'),
#  (0.0, 'AMGIA(t-3)'),
#  (0.0, 'AMGN(t-1)'),
#  (-0.0, 'AMGN(t-2)'),
#  (0.0, 'AMGN(t-3)'),
#  (0.0, 'AMH(t-1)'),
#  (-0.0, 'AMH(t-2)'),
#  (-0.0, 'AMH(t-3)'),
#  (-0.0, 'AMHC(t-1)'),
#  (-0.0, 'AMHC(t-2)'),
#  (0.0, 'AMHC(t-3)'),
#  (-0.0, 'AMI(t-1)'),
#  (0.0, 'AMI(t-2)'),
#  (-0.0, 'AMI(t-3)'),
#  (0.0, 'AMIE(t-1)'),
#  (-0.0, 'AMIE(t-2)'),
#  (-0.0, 'AMIE(t-3)'),
#  (0.0, 'AMKR(t-1)'),
#  (0.0, 'AMKR(t-2)'),
#  (-0.0, 'AMKR(t-3)'),
#  (0.0, 'AMLN(t-1)'),
#  (0.0, 'AMLN(t-2)'),
#  (0.0, 'AMLN(t-3)'),
#  (0.0, 'AMMD(t-1)'),
#  (-0.0, 'AMMD(t-2)'),
#  (0.0, 'AMMD(t-3)'),
#  (0.0, 'AMN(t-1)'),
#  (-0.0, 'AMN(t-2)'),
#  (0.0, 'AMN(t-3)'),
#  (0.0, 'AMNB(t-1)'),
#  (-0.0, 'AMNB(t-2)'),
#  (-0.0, 'AMNB(t-3)'),
#  (-0.0, 'AMR(t-1)'),
#  (-0.0, 'AMR(t-2)'),
#  (0.0, 'AMR(t-3)'),
#  (0.0, 'AMRI(t-1)'),
#  (-0.0, 'AMRI(t-2)'),
#  (-0.0, 'AMRI(t-3)'),
#  (0.0, 'AMSC(t-1)'),
#  (-0.0, 'AMSC(t-2)'),
#  (0.0, 'AMSC(t-3)'),
#  (-0.0, 'AMSG(t-1)'),
#  (0.0, 'AMSG(t-2)'),
#  (0.0, 'AMSG(t-3)'),
#  (-0.0, 'AMSWA(t-2)'),
#  (0.0, 'AMSWA(t-3)'),
#  (0.0, 'AMSY(t-1)'),
#  (0.0, 'AMSY(t-2)'),
#  (0.0, 'AMSY(t-3)'),
#  (0.0, 'AMT(t-1)'),
#  (-0.0, 'AMT(t-2)'),
#  (0.0, 'AMT(t-3)'),
#  (0.0, 'AMTD(t-1)'),
#  (-0.0, 'AMTD(t-2)'),
#  (-0.0, 'AMTD(t-3)'),
#  (0.0, 'AMWD(t-1)'),
#  (0.0, 'AMWD(t-2)'),
#  (0.0, 'AMWD(t-3)'),
#  (0.0, 'AMZ(t-1)'),
#  (0.0, 'AMZ(t-2)'),
#  (0.0, 'AMZ(t-3)'),
#  (0.0, 'AMZN(t-1)'),
#  (0.0, 'AMZN(t-2)'),
#  (-0.0, 'AMZN(t-3)'),
#  (0.0, 'AN(t-1)'),
#  (-0.0, 'AN(t-2)'),
#  (-0.0, 'AN(t-3)'),
#  (-0.0, 'ANAD(t-1)'),
#  (-0.0, 'ANAD(t-2)'),
#  (0.0, 'ANAD(t-3)'),
#  (0.0, 'ANAT(t-1)'),
#  (-0.0, 'ANAT(t-2)'),
#  (-0.0, 'ANAT(t-3)'),
#  (0.0, 'AND(t-1)'),
#  (0.0, 'AND(t-2)'),
#  (-0.0, 'AND(t-3)'),
#  (-0.0, 'ANDE(t-1)'),
#  (0.0, 'ANDE(t-2)'),
#  (-0.0, 'ANDE(t-3)'),
#  (0.0, 'ANDR(t-1)'),
#  (0.0, 'ANDR(t-2)'),
#  (0.0, 'ANDR(t-3)'),
#  (-0.0, 'ANDW(t-1)'),
#  (-0.0, 'ANDW(t-2)'),
#  (-0.0, 'ANDW(t-3)'),
#  (0.0, 'ANEN(t-1)'),
#  (0.0, 'ANEN(t-2)'),
#  (-0.0, 'ANEN(t-3)'),
#  (0.0, 'ANF(t-1)'),
#  (0.0, 'ANF(t-2)'),
#  (0.0, 'ANF(t-3)'),
#  (0.0, 'ANFI(t-1)'),
#  (-0.0, 'ANFI(t-2)'),
#  (0.0, 'ANFI(t-3)'),
#  (-0.0, 'ANLY(t-1)'),
#  (0.0, 'ANLY(t-2)'),
#  (-0.0, 'ANLY(t-3)'),
#  (0.0, 'ANN(t-1)'),
#  (0.0, 'ANN(t-2)'),
#  (-0.0, 'ANN(t-3)'),
#  (0.0, 'ANSI(t-1)'),
#  (-0.0, 'ANSI(t-2)'),
#  (0.0, 'ANSI(t-3)'),
#  (-0.0, 'ANSR(t-1)'),
#  (-0.0, 'ANSR(t-2)'),
#  (-0.0, 'ANSR(t-3)'),
#  (-0.0, 'ANSS(t-1)'),
#  (0.0, 'ANSS(t-2)'),
#  (0.0, 'ANSS(t-3)'),
#  (0.0, 'ANST(t-1)'),
#  (-0.0, 'ANST(t-2)'),
#  (0.0, 'ANST(t-3)'),
#  (-0.0, 'ANT(t-1)'),
#  (-0.0, 'ANT(t-2)'),
#  (0.0, 'ANT(t-3)'),
#  (-0.0, 'ANTR(t-1)'),
#  (-0.0, 'ANTR(t-2)'),
#  (-0.0, 'ANTR(t-3)'),
#  (0.0, 'AOC(t-1)'),
#  (-0.0, 'AOC(t-2)'),
#  (0.0, 'AOC(t-3)'),
#  (-0.0, 'AOL(t-1)'),
#  (0.0, 'AOL(t-2)'),
#  (-0.0, 'AOL(t-3)'),
#  (-0.0, 'AOR(t-1)'),
#  (-0.0, 'AOR(t-2)'),
#  (0.0, 'AOR(t-3)'),
#  (0.0, 'AOS(t-1)'),
#  (-0.0, 'AOS(t-2)'),
#  (0.0, 'AOS(t-3)'),
#  (-0.0, 'AOT(t-1)'),
#  (-0.0, 'AOT(t-2)'),
#  (0.0, 'AOT(t-3)'),
#  (-0.0, 'AP(t-1)'),
#  (-0.0, 'AP(t-2)'),
#  (0.0, 'AP(t-3)'),
#  (0.0, 'APA(t-1)'),
#  (0.0, 'APA(t-2)'),
#  (-0.0, 'APA(t-3)'),
#  (0.0, 'APAC(t-1)'),
#  (-0.0, 'APAC(t-2)'),
#  (-0.0, 'APAC(t-3)'),
#  (0.0, 'APAT(t-1)'),
#  (0.0, 'APAT(t-2)'),
#  (-0.0, 'APAT(t-3)'),
#  (0.0, 'APC(t-1)'),
#  (-0.0, 'APC(t-2)'),
#  (-0.0, 'APC(t-3)'),
#  (0.0, 'APCC(t-1)'),
#  (0.0, 'APCC(t-2)'),
#  (0.0, 'APCC(t-3)'),
#  (0.0, 'APD(t-1)'),
#  (-0.0, 'APD(t-2)'),
#  (0.0, 'APD(t-3)'),
#  (0.0, 'APH(t-1)'),
#  (-0.0, 'APH(t-2)'),
#  (0.0, 'APH(t-3)'),
#  (-0.0, 'APHT(t-1)'),
#  (0.0, 'APHT(t-2)'),
#  (0.0, 'APHT(t-3)'),
#  (0.0, 'APLX(t-2)'),
#  (-0.0, 'APLX(t-3)'),
#  (-0.0, 'APN(t-1)'),
#  (0.0, 'APN(t-2)'),
#  (0.0, 'APN(t-3)'),
#  (0.0, 'APOG(t-1)'),
#  (-0.0, 'APOG(t-2)'),
#  (-0.0, 'APOG(t-3)'),
#  (0.0, 'APOL(t-1)'),
#  (0.0, 'APOL(t-2)'),
#  (-0.0, 'APOL(t-3)'),
#  (0.0, 'APPA(t-1)'),
#  (-0.0, 'APPA(t-2)'),
#  (0.0, 'APPA(t-3)'),
#  (-0.0, 'APPB(t-1)'),
#  (0.0, 'APPB(t-2)'),
#  (-0.0, 'APPB(t-3)'),
#  (0.0, 'APPX(t-1)'),
#  (0.0, 'APPX(t-2)'),
#  (-0.0, 'APPX(t-3)'),
#  (0.0, 'APRS(t-1)'),
#  (-0.0, 'APRS(t-2)'),
#  (0.0, 'APRS(t-3)'),
#  (-0.0, 'APS(t-1)'),
#  (-0.0, 'APS(t-2)'),
#  (0.0, 'APS(t-3)'),
#  (0.0, 'APSG(t-1)'),
#  (0.0, 'APSG(t-2)'),
#  (0.0, 'APSG(t-3)'),
#  (0.0, 'APTI(t-1)'),
#  (-0.0, 'APTI(t-2)'),
#  (0.0, 'APTI(t-3)'),
#  (-0.0, 'APWR(t-1)'),
#  (0.0, 'APWR(t-2)'),
#  (-0.0, 'APWR(t-3)'),
#  (-0.0, 'ARB(t-1)'),
#  (-0.0, 'ARB(t-2)'),
#  (0.0, 'ARB(t-3)'),
#  (0.0, 'ARBA(t-1)'),
#  (-0.0, 'ARBA(t-2)'),
#  (0.0, 'ARBA(t-3)'),
#  (-0.0, 'ARDI(t-1)'),
#  (-0.0, 'ARDI(t-2)'),
#  (-0.0, 'ARDI(t-3)'),
#  (-0.0, 'ARDM(t-1)'),
#  (0.0, 'ARDM(t-2)'),
#  (-0.0, 'ARDM(t-3)'),
#  (-0.0, 'ARG(t-1)'),
#  (-0.0, 'ARG(t-2)'),
#  (-0.0, 'ARG(t-3)'),
#  (-0.0, 'ARGN(t-1)'),
#  (0.0, 'ARGN(t-2)'),
#  (0.0, 'ARGN(t-3)'),
#  (0.0, 'ARIA(t-1)'),
#  (-0.0, 'ARIA(t-2)'),
#  (0.0, 'ARIA(t-3)'),
#  (-0.0, 'ARJ(t-1)'),
#  (0.0, 'ARJ(t-2)'),
#  (0.0, 'ARJ(t-3)'),
#  (0.0, 'ARL(t-1)'),
#  (-0.0, 'ARL(t-2)'),
#  (-0.0, 'ARL(t-3)'),
#  (0.0, 'ARM(t-1)'),
#  (-0.0, 'ARM(t-2)'),
#  (-0.0, 'ARM(t-3)'),
#  (0.0, 'ARNA(t-1)'),
#  (0.0, 'ARNA(t-2)'),
#  (-0.0, 'ARNA(t-3)'),
#  (-0.0, 'ARO(t-1)'),
#  (0.0, 'ARO(t-2)'),
#  (-0.0, 'ARO(t-3)'),
#  (-0.0, 'AROW(t-1)'),
#  (-0.0, 'AROW(t-2)'),
#  (0.0, 'AROW(t-3)'),
#  (-0.0, 'ARQL(t-1)'),
#  (-0.0, 'ARQL(t-2)'),
#  (0.0, 'ARQL(t-3)'),
#  (0.0, 'ARRO(t-1)'),
#  (-0.0, 'ARRO(t-2)'),
#  (0.0, 'ARRO(t-3)'),
#  (0.0, 'ARRS(t-1)'),
#  (-0.0, 'ARRS(t-2)'),
#  (0.0, 'ARRS(t-3)'),
#  (0.0, 'ARRY(t-1)'),
#  (-0.0, 'ARRY(t-2)'),
#  (-0.0, 'ARRY(t-3)'),
#  (0.0, 'ARTC(t-1)'),
#  (0.0, 'ARTC(t-2)'),
#  (-0.0, 'ARTC(t-3)'),
#  (-0.0, 'ARTG(t-1)'),
#  (0.0, 'ARTG(t-2)'),
#  (0.0, 'ARTG(t-3)'),
#  (0.0, 'ARTI(t-1)'),
#  (0.0, 'ARTI(t-2)'),
#  (0.0, 'ARTI(t-3)'),
#  (-0.0, 'ARW(t-1)'),
#  (-0.0, 'ARW(t-2)'),
#  (-0.0, 'ARW(t-3)'),
#  (-0.0, 'ARXX(t-1)'),
#  (0.0, 'ARXX(t-2)'),
#  (-0.0, 'ARXX(t-3)'),
#  (0.0, 'ASAA(t-3)'),
#  (0.0, 'ASBC(t-1)'),
#  (0.0, 'ASBC(t-2)'),
#  (0.0, 'ASBC(t-3)'),
#  (-0.0, 'ASBP(t-1)'),
#  (0.0, 'ASBP(t-2)'),
#  (0.0, 'ASBP(t-3)'),
#  (0.0, 'ASCA(t-1)'),
#  (0.0, 'ASCA(t-2)'),
#  (-0.0, 'ASCA(t-3)'),
#  (0.0, 'ASCL(t-1)'),
#  (0.0, 'ASCL(t-2)'),
#  (-0.0, 'ASCL(t-3)'),
#  (0.0, 'ASD(t-1)'),
#  (-0.0, 'ASD(t-2)'),
#  (-0.0, 'ASD(t-3)'),
#  (0.0, 'ASF(t-1)'),
#  (-0.0, 'ASF(t-2)'),
#  (-0.0, 'ASF(t-3)'),
#  (-0.0, 'ASFI(t-1)'),
#  (-0.0, 'ASFI(t-2)'),
#  (-0.0, 'ASFI(t-3)'),
#  (-0.0, 'ASGN(t-1)'),
#  (0.0, 'ASGN(t-2)'),
#  (-0.0, 'ASGN(t-3)'),
#  (0.0, 'ASGR(t-1)'),
#  (0.0, 'ASGR(t-2)'),
#  (-0.0, 'ASGR(t-3)'),
#  (-0.0, 'ASH(t-1)'),
#  (0.0, 'ASH(t-2)'),
#  (0.0, 'ASH(t-3)'),
#  (0.0, 'ASIA(t-1)'),
#  (-0.0, 'ASIA(t-2)'),
#  (0.0, 'ASIA(t-3)'),
#  (0.0, 'ASKJ(t-1)'),
#  (0.0, 'ASKJ(t-2)'),
#  (-0.0, 'ASKJ(t-3)'),
#  (0.0, 'ASO(t-1)'),
#  (0.0, 'ASO(t-2)'),
#  (-0.0, 'ASO(t-3)'),
#  (-0.0, 'ASPM(t-1)'),
#  (-0.0, 'ASPM(t-2)'),
#  (0.0, 'ASPM(t-3)'),
#  (-0.0, 'ASPT(t-1)'),
#  (0.0, 'ASPT(t-2)'),
#  (-0.0, 'ASPT(t-3)'),
#  (-0.0, 'ASRV(t-3)'),
#  (0.0, 'ASTE(t-1)'),
#  (-0.0, 'ASTE(t-2)'),
#  (0.0, 'ASTE(t-3)'),
#  (0.0, 'ASTM(t-1)'),
#  (0.0, 'ASTM(t-2)'),
#  (-0.0, 'ASTM(t-3)'),
#  (-0.0, 'ASYT(t-1)'),
#  (-0.0, 'ASYT(t-2)'),
#  (0.0, 'ASYT(t-3)'),
#  (0.0, 'AT(t-1)'),
#  (0.0, 'AT(t-2)'),
#  (0.0, 'AT(t-3)'),
#  (0.0, 'ATAC(t-1)'),
#  (-0.0, 'ATAC(t-2)'),
#  (-0.0, 'ATAC(t-3)'),
#  (0.0, 'ATCO(t-1)'),
#  (0.0, 'ATCO(t-2)'),
#  (-0.0, 'ATCO(t-3)'),
#  (-0.0, 'ATG(t-1)'),
#  (0.0, 'ATG(t-2)'),
#  (-0.0, 'ATG(t-3)'),
#  (0.0, 'ATH(t-1)'),
#  (-0.0, 'ATH(t-2)'),
#  (-0.0, 'ATH(t-3)'),
#  (0.0, 'ATI(t-1)'),
#  (0.0, 'ATI(t-2)'),
#  (0.0, 'ATK(t-1)'),
#  (-0.0, 'ATK(t-2)'),
#  (-0.0, 'ATK(t-3)'),
#  (0.0, 'ATMI(t-1)'),
#  (0.0, 'ATMI(t-2)'),
#  (0.0, 'ATMI(t-3)'),
#  (0.0, 'ATML(t-1)'),
#  (0.0, 'ATML(t-2)'),
#  (-0.0, 'ATML(t-3)'),
#  (0.0, 'ATN(t-1)'),
#  (0.0, 'ATN(t-2)'),
#  (0.0, 'ATN(t-3)'),
#  (0.0, 'ATO(t-1)'),
#  (0.0, 'ATO(t-2)'),
#  (0.0, 'ATO(t-3)'),
#  (0.0, 'ATPG(t-1)'),
#  (-0.0, 'ATPG(t-2)'),
#  (0.0, 'ATPG(t-3)'),
#  (-0.0, 'ATR(t-1)'),
#  (0.0, 'ATR(t-2)'),
#  (-0.0, 'ATR(t-3)'),
#  (0.0, 'ATRS(t-1)'),
#  (-0.0, 'ATRS(t-2)'),
#  (-0.0, 'ATRS(t-3)'),
#  (-0.0, 'ATRX(t-1)'),
#  (0.0, 'ATRX(t-2)'),
#  (0.0, 'ATRX(t-3)'),
#  (0.0, 'ATSI(t-1)'),
#  (0.0, 'ATSI(t-2)'),
#  (0.0, 'ATSI(t-3)'),
#  (0.0, 'ATSN(t-1)'),
#  (-0.0, 'ATSN(t-2)'),
#  (0.0, 'ATSN(t-3)'),
#  (0.0, 'ATTL(t-1)'),
#  (0.0, 'ATTL(t-2)'),
#  (0.0, 'ATTL(t-3)'),
#  (0.0, 'ATU(t-1)'),
#  (-0.0, 'ATU(t-2)'),
#  (0.0, 'ATU(t-3)'),
#  (0.0, 'ATVI(t-1)'),
#  (-0.0, 'ATVI(t-2)'),
#  (0.0, 'ATVI(t-3)'),
#  (0.0, 'ATW(t-1)'),
#  (-0.0, 'ATW(t-2)'),
#  (0.0, 'ATW(t-3)'),
#  (0.0, 'AUGT(t-1)'),
#  (0.0, 'AUGT(t-2)'),
#  (-0.0, 'AUGT(t-3)'),
#  (0.0, 'AULT(t-1)'),
#  (0.0, 'AULT(t-2)'),
#  (-0.0, 'AULT(t-3)'),
#  (0.0, 'AV(t-1)'),
#  (0.0, 'AV(t-2)'),
#  (-0.0, 'AV(t-3)'),
#  (0.0, 'AVA(t-1)'),
#  (-0.0, 'AVA(t-2)'),
#  (0.0, 'AVA(t-3)'),
#  (0.0, 'AVAN(t-1)'),
#  (0.0, 'AVAN(t-2)'),
#  (-0.0, 'AVAN(t-3)'),
#  (-0.0, 'AVCI(t-1)'),
#  (0.0, 'AVCI(t-2)'),
#  (-0.0, 'AVCI(t-3)'),
#  (-0.0, 'AVCT(t-1)'),
#  (-0.0, 'AVCT(t-2)'),
#  (0.0, 'AVCT(t-3)'),
#  (-0.0, 'AVD(t-1)'),
#  (-0.0, 'AVD(t-2)'),
#  (0.0, 'AVD(t-3)'),
#  (0.0, 'AVEA(t-1)'),
#  (-0.0, 'AVEA(t-2)'),
#  (-0.0, 'AVEA(t-3)'),
#  (-0.0, 'AVGN(t-1)'),
#  (0.0, 'AVGN(t-2)'),
#  (-0.0, 'AVGN(t-3)'),
#  (-0.0, 'AVGO(t-1)'),
#  (-0.0, 'AVGO(t-2)'),
#  (-0.0, 'AVGO(t-3)'),
#  (-0.0, 'AVID(t-1)'),
#  (0.0, 'AVID(t-2)'),
#  (0.0, 'AVID(t-3)'),
#  (-0.0, 'AVL(t-1)'),
#  (-0.0, 'AVL(t-2)'),
#  (0.0, 'AVL(t-3)'),
#  (0.0, 'AVLN(t-1)'),
#  (0.0, 'AVLN(t-2)'),
#  (0.0, 'AVLN(t-3)'),
#  (0.0, 'AVN(t-1)'),
#  (-0.0, 'AVN(t-2)'),
#  (0.0, 'AVN(t-3)'),
#  (-0.0, 'AVNX(t-1)'),
#  (0.0, 'AVNX(t-2)'),
#  (-0.0, 'AVNX(t-3)'),
#  (-0.0, 'AVO(t-1)'),
#  (-0.0, 'AVO(t-2)'),
#  (0.0, 'AVO(t-3)'),
#  (0.0, 'AVP(t-1)'),
#  (0.0, 'AVP(t-2)'),
#  (0.0, 'AVP(t-3)'),
#  (-0.0, 'AVSR(t-1)'),
#  (0.0, 'AVSR(t-2)'),
#  (-0.0, 'AVSR(t-3)'),
#  (-0.0, 'AVT(t-1)'),
#  (0.0, 'AVT(t-2)'),
#  (-0.0, 'AVT(t-3)'),
#  (0.0, 'AVX(t-1)'),
#  (-0.0, 'AVX(t-2)'),
#  (0.0, 'AVX(t-3)'),
#  (0.0, 'AVXT(t-1)'),
#  (-0.0, 'AVXT(t-2)'),
#  (0.0, 'AVXT(t-3)'),
#  (0.0, 'AVY(t-1)'),
#  (-0.0, 'AVY(t-2)'),
#  (-0.0, 'AVY(t-3)'),
#  (0.0, 'AW(t-1)'),
#  (-0.0, 'AW(t-2)'),
#  (0.0, 'AW(t-3)'),
#  (0.0, 'AWA(t-1)'),
#  (0.0, 'AWA(t-2)'),
#  (0.0, 'AWA(t-3)'),
#  (0.0, 'AWBC(t-1)'),
#  (0.0, 'AWBC(t-2)'),
#  (0.0, 'AWBC(t-3)'),
#  (0.0, 'AWE(t-1)'),
#  (-0.0, 'AWE(t-2)'),
#  (-0.0, 'AWE(t-3)'),
#  (0.0, 'AWGI(t-1)'),
#  (-0.0, 'AWGI(t-2)'),
#  (0.0, 'AWGI(t-3)'),
#  (0.0, 'AWK(t-1)'),
#  (-0.0, 'AWK(t-2)'),
#  (-0.0, 'AWK(t-3)'),
#  (-0.0, 'AWR(t-1)'),
#  (-0.0, 'AWR(t-2)'),
#  (-0.0, 'AWR(t-3)'),
#  (-0.0, 'AWRE(t-1)'),
#  (0.0, 'AWRE(t-2)'),
#  (0.0, 'AWRE(t-3)'),
#  (-0.0, 'AXE(t-1)'),
#  (0.0, 'AXE(t-2)'),
#  (-0.0, 'AXE(t-3)'),
#  (0.0, 'AXL(t-1)'),
#  (0.0, 'AXL(t-2)'),
#  (0.0, 'AXL(t-3)'),
#  (0.0, 'AXO(t-1)'),
#  (0.0, 'AXO(t-2)'),
#  (-0.0, 'AXO(t-3)'),
#  (0.0, 'AXP(t-1)'),
#  (-0.0, 'AXP(t-2)'),
#  (-0.0, 'AXP(t-3)'),
#  (-0.0, 'AXTI(t-1)'),
#  (0.0, 'AXTI(t-2)'),
#  (-0.0, 'AXTI(t-3)'),
#  (0.0, 'AYE(t-1)'),
#  (-0.0, 'AYE(t-2)'),
#  (0.0, 'AYE(t-3)'),
#  (-0.0, 'AYI(t-1)'),
#  (-0.0, 'AYI(t-2)'),
#  (0.0, 'AYI(t-3)'),
#  (0.0, 'AZO(t-1)'),
#  (-0.0, 'AZO(t-2)'),
#  (0.0, 'AZO(t-3)'),
#  (0.0, 'AZPN(t-1)'),
#  (0.0, 'AZPN(t-2)'),
#  (0.0, 'AZPN(t-3)'),
#  (0.0, 'AZR(t-1)'),
#  (-0.0, 'AZR(t-2)'),
#  (0.0, 'AZR(t-3)'),
#  (-0.0, 'B(t-1)'),
#  (0.0, 'B(t-2)'),
#  (0.0, 'B(t-3)'),
#  (0.0, 'BA(t-1)'),
#  (-0.0, 'BA(t-2)'),
#  (0.0, 'BA(t-3)'),
#  (0.0, 'BAC(t-1)'),
#  (-0.0, 'BAC(t-2)'),
#  (-0.0, 'BAC(t-3)'),
#  (-0.0, 'BANF(t-1)'),
#  (-0.0, 'BANF(t-2)'),
#  (0.0, 'BANF(t-3)'),
#  (0.0, 'BANR(t-3)'),
#  (0.0, 'BARI(t-1)'),
#  (0.0, 'BARI(t-2)'),
#  (0.0, 'BARI(t-3)'),
#  (-0.0, 'BARZ(t-1)'),
#  (-0.0, 'BARZ(t-2)'),
#  (0.0, 'BARZ(t-3)'),
#  ...]

# %%
round(reg.score(x_temp, y_temp.iloc[:,2])*100, 2)
# Out:
# 0.0

# %%
# parou aqui 
def LASSO_reg(x, y, t, i):
    """
    função que recebe dois dataframes e um argumento t
    dataframe x: dataframe com candidatos a preditores
    dataframe y: dataframe com 250 ações escolhidas aleatoriamente
    t: variável de corte da janela de estimação (t = {0,...,356})
    i: índice referente à ação que estamos prevendo
    """
    x_temp = x[t:30+t]
    x_temp = ( x_temp - x_temp.mean() ) / x_temp.std()
    x_temp = x_temp.dropna(axis=1)
    y_temp = y[t:30+t]
    model = LassoCV(cv=10, random_state=0, max_iter=10000)
    model.fit(x_temp, y_temp.iloc[:,i])
    reg = Lasso(alpha=model.alpha_)
    reg.fit(x_temp, y_temp.iloc[:,i])
